# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
# application_df = pd.read_csv("Resources/charity_data.csv")
application_df = pd.read_csv('https://raw.githubusercontent.com/dany-roman/charity_funding_predictor/master/Resources/charity_data.csv')
application_df.head()
# Out:
#         EIN                                      NAME  ... ASK_AMT IS_SUCCESSFUL
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB  ...    5000             1
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR  ...  108590             1
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  ...    5000             0
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  ...    6692             1
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT  ...  142590             1
#
# [5 rows x 12 columns]

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['EIN','NAME'], axis=1)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION  ... ASK_AMT IS_SUCCESSFUL
# 0              T10       Independent  ...    5000             1
# 1               T3       Independent  ...  108590             1
# 2               T5  CompanySponsored  ...    5000             0
# 3               T3  CompanySponsored  ...    6692             1
# 4               T3       Independent  ...  142590             1
#
# [5 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df.groupby('APPLICATION_TYPE')['APPLICATION_TYPE'].count()
# Out:
# APPLICATION_TYPE
# T10      528
# T12       27
# T13       66
# T14        3
# T15        2
# T17        1
# T19     1065
# T2        16
# T25        3
# T29        2
# T3     27037
# T4      1542
# T5      1173
# T6      1216
# T7       725
# T8       737
# T9       156
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ["T9",'T12','T13','T14','T15','T17','T2','T25','T29']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
count = application_df.groupby('CLASSIFICATION')['CLASSIFICATION'].count()
count = count.sort_values(ascending=False)
count
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C1820        1
# C1732        1
# C1728        1
# C1580        1
# C1900        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
count[count>1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1278       10
# C1238       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C4100        6
# C1720        6
# C1600        5
# C1257        5
# C0           3
# C2710        3
# C1260        3
# C1234        2
# C1246        2
# C3200        2
# C1256        2
# C1267        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = ['C1700', 'C4000',
       'C5000', 'C1270', 'C2700', 'C2800', 'C7100', 'C1300', 'C1280', 'C1230',
       'C1400', 'C2300', 'C7200', 'C1240', 'C8000', 'C7120', 'C1500', 'C1800',
       'C6000', 'C1250', 'C8200', 'C1278', 'C1238', 'C1235', 'C1237', 'C7210',
       'C1720', 'C4100', 'C2400', 'C1600', 'C1257', 'C2710', 'C1260', 'C0',
       'C1267', 'C1246', 'C1256', 'C3200', 'C1234', 'C4500', 'C4120', 'C5200',
       'C3700', 'C6100', 'C4200', 'C1900', 'C2600', 'C1728', 'C1236', 'C1245',
       'C1248', 'C1283', 'C1370', 'C1570', 'C1580', 'C1732', 'C2570', 'C1820',
       'C2150', 'C2170', 'C2190', 'C2380', 'C2500', 'C2561', 'C8210']

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
X_dummies = pd.get_dummies(application_df)
X_dummies
# Out:
#        STATUS   ASK_AMT  ...  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0           1      5000  ...                         1                         0
# 1           1    108590  ...                         1                         0
# 2           1      5000  ...                         1                         0
# 3           1      6692  ...                         1                         0
# 4           1    142590  ...                         1                         0
# ...       ...       ...  ...                       ...                       ...
# 34294       1      5000  ...                         1                         0
# 34295       1      5000  ...                         1                         0
# 34296       1      5000  ...                         1                         0
# 34297       1      5000  ...                         1                         0
# 34298       1  36500179  ...                         1                         0
#
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = X_dummies.drop('IS_SUCCESSFUL',axis=1).values
y_label = X_dummies['IS_SUCCESSFUL'].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y_label, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
features = len(X_train.columns)

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=8, input_dim=features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=5, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 8)                 368
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 45
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 6
# ...
# Total params: 419
# Trainable params: 419
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=10)
# Out:
# Epoch 1/10
# 804/804 [==============================] - 2s 2ms/step - loss: 0.2615 - accuracy: 0.9116
# Epoch 2/10
# 804/804 [==============================] - 1s 1ms/step - loss: 0.0119 - accuracy: 0.9979
# Epoch 3/10
# 804/804 [==============================] - 1s 1ms/step - loss: 0.0034 - accuracy: 0.9996
# Epoch 4/10
# 804/804 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.9998
# Epoch 5/10
# 804/804 [==============================] - 1s 2ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 6/10
# 804/804 [==============================] - 1s 2ms/step - loss: 5.1745e-04 - accuracy: 0.9998
# Epoch 7/10
# 804/804 [==============================] - 1s 1ms/step - loss: 3.1247e-04 - accuracy: 0.9998
# Epoch 8/10
# 804/804 [==============================] - 1s 1ms/step - loss: 2.3683e-04 - accuracy: 0.9999
# Epoch 9/10
# 804/804 [==============================] - 1s 1ms/step - loss: 1.2934e-04 - accuracy: 1.0000
# Epoch 10/10
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {round(model_loss,2)*100}%, Accuracy: {round(model_accuracy,2)*100}%")
# Out:
# 268/268 - 0s - loss: 1.9147e-04 - accuracy: 0.9999
# Loss: 0.0%, Accuracy: 100.0%

# %%
# Export our model to HDF5 file
# nn.to_hdf('AlphabetSoupCharity.h5')

nn.save("AlphabetSoupCharity.h5")
